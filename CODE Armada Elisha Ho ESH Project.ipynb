# %% [markdown]
# <a href="https://colab.research.google.com/github/elisaysha/Project.Armada/blob/main/FINAL_Armada_Elisha_Ho_ESH_WA3_Computing_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ARMADA by elisaysha_
#
# **Note: Game is meant to run on Google Colab*
#
# To start game:
# - Press connect at top right
# - Go to the bottom and run the code at that says "PLEASE RUN BEFORE MAIN"
# - Then run the code at the top.
# - Have fun! 🙂

# %%
import random
from google.colab import output
import time
output.clear()
#Variables:
empty = "~"
hit = "X"
miss = "O"
submarine = "S"
aircraft_carrier = "A"
radar = "R"
missile = "M"
destroyer = "D"
yourmaplist = []
botmaplist = []
playerresource = 0
botresource = 0
shiptypel = [submarine,aircraft_carrier,radar,missile,destroyer]
shiptypesd = {"Submarine": submarine, "Aircraft Carrier":aircraft_carrier,"Destroyer":destroyer,"Missile Boat":missile,"Radar":radar }
devMode = False
boardsize = 8
devname = "elisaysha"
#size of board: 8x8
#number of ships tbc: 7

#User defined functions:
def shipmenu():
    print(f"At your service Commander {name}!\nThis is your current fleet, consisting of:")
    openfile("ShipMenu.txt",True)
def createmap(): #Explained in PPT
    mapl = []
    for i in range(boardsize):
        row = []
        for i in range(boardsize):     #12 spaces in row
            row.append(empty)
        mapl.append(row)                #12 rows in mapslist
    return mapl
def printmap(maplist):
    count = 0
    print("  ",end = "")
    for i in range(boardsize):
        if i == boardsize-1:
            print(i)
            break
        print(i,end = " ")
    for eachrow in maplist:
        print(count,end = ' ')
        count += 1
        for eachspace in eachrow:
            print(eachspace, end=' ')   #prints every space with a " " w/o adding it to list
        print()                         #new line w/o end="" affecting
def shipplace():
    while True: #Manually places ships in different rows and colums in the map
        place = input("Enter coordinates of vessel(row, column seperated by a space): ").split()
        if (len(place) ==2)and(place[0].isdigit())and(place[1].isdigit())and(int(place[0]) >-1) and (int(place[0])<boardsize) and (int(place[1]) >-1):
            if (int(place[1])<boardsize) and (yourmaplist[int(place[0])][int(place[1])]=="~"):
                row = place[0]
                col = place[1]
                break
            else:
                print("Invalid input! Input must be a valid coordinate that is free.")
        else:
            print("Invalid input! Input must be a valid coordinate that is free.")
    while True:
        vessel = input("Enter vessel type(Submarine, Aircraft Carrier, Destroyer, Missile Boat, Radar)")
        if vessel in shiptypesd: #Player chooses what ship type to use e.g. Submarine, Aircraft Carrier etc
            break
        else:
            print("Invalid input!")
    print(row,col,vessel)
    return row, col, vessel
def randomshipplace(maplist): #Randomly chooses what ship type to use e.g. Submarine, Aircraft Carrier etc
    count = 0
    shiptypeldef = [submarine,aircraft_carrier,radar,missile,destroyer,radar,submarine]
    while count < 7:
        row = random.randint(0, boardsize -1 )
        col = random.randint(0, boardsize -1 )
        if maplist[row][col] == empty:
            randomship = shiptypeldef[random.randint(0,len(shiptypeldef)-1)]
            maplist[row][col] = randomship
            count += 1
            shiptypeldef.remove(randomship)
    return maplist
def playerturn(botforplayermap,yourmaplist,playerresource,shipspresent,botmaplist):
    print("Your map:")
    printmap(yourmaplist)
    if devMode == True:
        print("Answer key:")
        printmap(botmaplist)
    print("Enemy side:")
    printmap(botforplayermap)

    while True:
        target = input("Select target coordinate(row, column seperated by a space): ").split()
        if (len(target) ==2)and(target[0].isdigit())and(target[1].isdigit())and(int(target[0]) >-1) and (int(target[0])<boardsize) and (int(target[1]) >-1)and (int(target[1])<boardsize):
            if botmaplist[int(target[0])][int(target[1])] in shiptypel:
                botforplayermap[int(target[0])][int(target[1])] = hit
                output.clear()
                print("Your map:")
                printmap(yourmaplist)
                if devMode == True:
                    print("Answer key:")
                    printmap(botmaplist)
                print("Enemy side:")
                printmap(botforplayermap)
                print("Hit!")
                break
            elif botmaplist[int(target[0])][int(target[1])] == empty:
                botforplayermap[int(target[0])][int(target[1])] = miss

                output.clear()
                print("Your map:")
                printmap(yourmaplist)
                if devMode == True:
                    print("Answer key:")
                    printmap(botmaplist)
                print("Enemy side:")
                printmap(botforplayermap)
                print("Miss...")
                break
            elif botmaplist[int(target[0])][int(target[1])] == "U":
                chance5050 = random.randint(0,2)
                if chance5050 == 0:
                    botforplayermap[row][col] = hit
                else:
                    print("Sonars are hearing small explosions from a submarine at this coordinate. Seems like they've dodged a bullet!")
                    botforplayermap[row][col] = "U"
                    print("Your map:")
                    printmap(yourmaplist)
                    if devMode == True:
                        print("Answer key:")
                        printmap(botmaplist)
                    print("Enemy side:")
                    printmap(botforplayermap)
                    print("Hit!")
                    break

        else:
            print("Invalid input! Input must be a valid coordinate that is free.")
    if playerresource >= 300:
        special = input(f"Would you like to use an ability? You have {playerresource} Credits. (Y/any other input)")
        output.clear()
        if special == "Y":
            while True:
                time.sleep(2)
                output.clear()
                if playerresource >= 300:
                    shippresent = shipspresent(yourmaplist)
                    shipmenu()
                    ability = input(f"Which vessel ability would you like to pick?{shippresent}")
                    if (ability == "S"):
                        if playerresource >= 350:
                            if ability in shippresent:
                                yourmaplist,playerresource = special_S(yourmaplist,playerresource)
                                printmap(yourmaplist)
                                break
                            else:
                                print("No submarines in the field...\nTry another ship")
                                input("Enter anything to continue")
                                output.clear()
                        else:
                            print("You don't have sufficient credits for any attack at all")
                    elif ability == "A":
                        if playerresource >= 400:
                            if ability in shippresent:
                                yourmaplist,botmaplist,botforplayermap,playerresource = special_A(yourmaplist,botmaplist,botforplayermap,playerresource)

                                break
                            else:
                                print("No Aircraft Carriers in the field...\nTry another ship")
                                input("Enter anything to continue")
                                output.clear()
                        else:
                            print("You don't have sufficient credits.")
                    elif ability == "D":
                        if ability in shippresent:
                            botforplayermap,botmaplist,playerresource = special_D(botforplayermap,botmaplist,playerresource)
                            break
                        else:
                            print("No Destroyers in the field...\nTry another ship")
                            input("Enter anything to continue")
                            output.clear()

                    elif ability == "M":
                        if ability in shippresent:
                            botforplayermap,botmaplist,playerresource = special_M(botforplayermap,botmaplist,playerresource)
                            break
                        else:
                            print("No Missile Boats in the field...\nTry another ship")
                            input("Enter anything to continue")
                            output.clear()
                    elif ability == "R":
                        if playerresource >= 650:
                            if ability in shippresent:
                                botmaplist,botforplayermap,playerresource = special_R(botmaplist,botforplayermap,playerresource)
                                break
                            else:
                                print("No Radars in the field...\nTry another ship")
                                input("Enter anything to continue")
                                output.clear()
                        else:
                            print("You don't have sufficient credits.")
                    else:
                        con = input("Invalid input, do you want to try another ability?(Y/any other input)")
                        if con != "Y":
                            break
                        output.clear()
                else:
                    print("You don't have sufficient credits...")
                    input("Enter anything to continue")
                    break
    else:
        print("You don't have sufficient credits to use any ship's ability... come back another time...")
        input("Enter anything to continue")
    output.clear()
    print("Cash left,", playerresource)
    print("Your map:")
    printmap(yourmaplist)
    if devMode == True:
        print("Answer key:")
        printmap(botmaplist)
    print("Enemy side:")
    printmap(botforplayermap)
    input("Enter anything to continue")
    return botforplayermap, yourmaplist,playerresource,shipspresent,botmaplist
#Functions for each special attack for  player
def special_S(map,playerresource):
    print("Submarine has received Emergency Action Message")
    printmap(map)
    while True:
        location = input("Enter the coordinate of the submarine you would like to hide(row, column seperated by a space): ").split()
        if (len(location) ==2)and(location[0].isdigit())and(location[1].isdigit())and(int(location[0]) >-1) and (int(location[0])<boardsize) and (int(location[1]) >-1)and (int(location[1])<boardsize):
            if map[int(location[0])][int(location[1])] == "S":
                output.clear()
                openfile("SubmarineImage.txt",False)
                print("Message is authenthic, awaiting captain's orders.")
                time.sleep(3)
                print("Forward room, seting depth one ze-ro feet.\nDIVE DIVE DIVE\nOxygen capacity set for the rest of the game.\nThis submarine will now have a 2/3 chance of dodging hits!\nGoing undercover(U)...")
                map[int(location[0])][int(location[1])] = "U"
                playerresource -= 350
                input("Enter anything to continue")
                break

            else:
                print("Message is not authenthic! No submarine here...")
        else:
            print("Invalid input! Input must be a real coordinate.")
    return map,playerresource
def special_A(yourmaplist,botmaplist,botforplayermap,playerresource):
    count = 0
    playerresource -= 400
    print("Scrambling strike fighters now...")
    time.sleep(3)
    print("Fighters launched, locking in 5 targets...")
    openfile("JetImage.txt",False)
    time.sleep(2)
    while count < 5:
        row = random.randint(0, boardsize -1 )
        col = random.randint(0, boardsize -1 )
        if botforplayermap[row][col] == empty: #Check if coordiante has been striked before
            count += 1
            if botmaplist[row][col] == empty: #Check if coordinate has an enemy target
                botforplayermap[row][col] = miss #Display miss on player screen
            elif botmaplist[row][col] in shiptypel: #Check if enemy ship there
                botforplayermap[row][col] = hit #Display hit on player screen
            elif botmaplist[row][col] == "U":
                chance5050 = random.randint(0,2)
                if chance5050 == 0:
                    botforplayermap[row][col] = hit
                else:
                    print("Sonars are hearing small explosions from a submarine at this coordinate. Seems like they've dodged a bullet!")
                    botforplayermap[row][col] = "U"
    print("Enemy side:")
    printmap(botforplayermap)
    return yourmaplist,botmaplist,botforplayermap,playerresource
def special_D(botforplayermap,botmaplist,playerresource): #Repeats "Player turn" 3 times
    playerresource -= 300
    print("Moving destroyer into position...\nSelect 3 targets to hit!")
    openfile("DestroyerImage.txt",False)
    time.sleep(2)
    count = 0
    while count != 3:
        printmap(botforplayermap)
        if devMode == True:
            print("Answer key:")
            printmap(botmaplist)
        target = input("Select target coordinate(row, column seperated by a space): ").split()
        count += 1
        output.clear()
        if (len(target) ==2)and(target[0].isdigit())and(target[1].isdigit())and(int(target[0]) >-1) and (int(target[0])<boardsize) and (int(target[1]) >-1)and (int(target[1])<boardsize):
            print("Loading shells...")
            openfile("DestroyerImage.txt",False)
            time.sleep(2)
            if botmaplist[int(target[0])][int(target[1])] in shiptypel:
                botforplayermap[int(target[0])][int(target[1])] = hit
            elif botmaplist[int(target[0])][int(target[1])] == empty:
                botforplayermap[int(target[0])][int(target[1])] = miss
            elif botmaplist[int(target[0])][int(target[1])] == "U":
                chance5050 = random.randint(0,2)
                if chance5050 == 0:
                    botforplayermap[int(target[0])][int(target[1])] = hit
                else:
                    print("Sonars are hearing small explosions from a submarine at this coordinate. Seems like they've dodged a bullet!")
                    botforplayermap[int(target[0])][int(target[1])] = "U"
        else:
            print("Invalid input! Input must be a valid coordinate that is free.")
    output.clear()
    print("Enemy side:")
    printmap(botforplayermap)
    return botforplayermap,botmaplist,playerresource
def special_M(botforplayermap,botmaplist,playerresource):
    playerresource -=300
    print("Arming missiles now...\nMissiles do splash damage, hitting the coordinates above, below, and beside too unless out of map.")
    printmap(botforplayermap)
    while True:
        target = input("Enter missile coordinates(row, column seperated by a space): ").split()
        if (len(target) ==2)and(target[0].isdigit())and(target[1].isdigit())and(int(target[0]) >-1) and (int(target[0])<boardsize) and (int(target[1]) >-1)and (int(target[1])<boardsize):
            if botmaplist[int(target[0])][int(target[1])] in shiptypel:
                botforplayermap[int(target[0])][int(target[1])] = hit
            elif botmaplist[int(target[0])][int(target[1])] == empty:
                botforplayermap[int(target[0])][int(target[1])] = miss
            elif botmaplist[int(target[0])][int(target[1])] == "U":
                chance5050 = random.randint(0,2)
                if chance5050 == 0:
                    botforplayermap[int(target[0])][int(target[1])] = hit
                else:
                    print("Sonars are hearing small explosions from a submarine at this coordinate. Seems like they've dodged a bullet!")
                    input("Enter anything to continue: ")
                    botforplayermap[int(target[0])][int(target[1])] = "U"

            if int(target[0])  > 0: #If a splash damage can be done on the left beside the missle
                if botmaplist[int(target[0])-1][int(target[1])] in shiptypel:
                    botforplayermap[int(target[0])-1][int(target[1])] = hit
                elif botmaplist[int(target[0])-1][int(target[1])] == empty:
                    botforplayermap[int(target[0])-1][int(target[1])] = miss
                elif botmaplist[int(target[0])-1][int(target[1])] == "U":
                    chance5050 = random.randint(0,2)
                    if chance5050 == 0:
                        botforplayermap[int(target[0])-1][int(target[1])] = hit
                    else:
                        print("Sonars are hearing small explosions from a submarine at this coordinate. Seems like they've dodged a bullet!")
                        input("Enter anything to continue")
                        botforplayermap[int(target[0])-1][int(target[1])] = "U"


            if int(target[0]) < boardsize -1  : #If splash damage can be done on the right beside the missle
                if botmaplist[int(target[0])+1][int(target[1])] in shiptypel:
                    botforplayermap[int(target[0])+1][int(target[1])] = hit
                elif botmaplist[int(target[0])+1][int(target[1])] == empty:
                    botforplayermap[int(target[0])+1][int(target[1])] = miss
                elif botmaplist[int(target[0])+1][int(target[1])] == "U":
                    chance5050 = random.randint(0,2)
                    if chance5050 == 0:
                        botforplayermap[int(target[0])+1][int(target[1])] = hit
                    else:
                        print("Sonars are hearing small explosions from a submarine at this coordinate. Seems like they've dodged a bullet!")
                        input("Enter anything to continue")
                        botforplayermap[int(target[0])+1][int(target[1])] = "U"
            if int(target[1]) < boardsize -1  : #If splash damage can be done on the bottom beside the missle
                if botmaplist[int(target[0])][int(target[1])+1] in shiptypel:
                    botforplayermap[int(target[0])][int(target[1]) +1 ] = hit
                elif botmaplist[int(target[0])][int(target[1])+1] == empty:
                    botforplayermap[int(target[0])][int(target[1])+1] = miss
                elif botmaplist[int(target[0])][int(target[1])+1] == "U":
                    chance5050 = random.randint(0,2)
                    if chance5050 == 0:
                        botforplayermap[int(target[0])][int(target[1])+1] = hit
                    else:
                        print("Sonars are hearing small explosions from a submarine at this coordinate. Seems like they've dodged a bullet!")
                        input("Enter anything to continue")
                        botforplayermap[int(target[0])][int(target[1])+1] = "U"
            if int(target[1])  > 0: #If splash damage can be done above beside missle
                if botmaplist[int(target[0])][int(target[1])-1] in shiptypel:
                    botforplayermap[int(target[0])][int(target[1]) -1 ] = hit
                elif botmaplist[int(target[0])][int(target[1])-1] == empty:
                    botforplayermap[int(target[0])][int(target[1])-1] = miss
                elif botmaplist[int(target[0])][int(target[1])-1] == "U":
                    chance5050 = random.randint(0,2)
                    if chance5050 == 0:
                        botforplayermap[int(target[0])][int(target[1])-1] = hit
                    else:
                        print("Sonars are hearing small explosions from a submarine at this coordinate. Seems like they've dodged a bullet!")
                        input("Enter anything to continue")
                        botforplayermap[int(target[0])][int(target[1])-1] = "U"
            break
        else:
            print("Invalid input! Input must be a valid coordinate that is free.")


    output.clear()
    print("Rockets away!")
    openfile("MissileImage.txt",False)
    input("Enter anything to continue")
    printmap(botforplayermap)
    return botforplayermap,botmaplist,playerresource

def special_R(botmaplist,botforplayermap,playerresource):
    playerresource -= 650
    print("Connecting to radar...")
    time.sleep(2)
    print("Connecting to satellite...")
    time.sleep(1)
    print("Sonar and radar disturbance found! Zooming in on enemy location...")
    time.sleep(1)
    openfile("RadarImage.txt",False)

    shippresent = shipspresent(botmaplist)
    chooseship = random.randint(0, len(shippresent) - 1)
    ship_identifier = shippresent[chooseship]
    row = -1
    col = -1

    ship_found = False
    for i in range(len(botmaplist)):
        for j in range(len(botmaplist[i])):
            if botmaplist[i][j] == ship_identifier:
                row = i
                col = j
                print(f"Enemy vessel in sector {row} {col}")
                ship_found = True #Finds a ship exact location
                break
        if ship_found:
            break
    input("Enter anything to continue: ")
    if playerresource >= 100:
        while True: #Option to shoot enemy vessel
            shootdown = input("Shoot down found enemy vessel? (Extra -100 Credits) (Y/N)")
            shootdown = shootdown.upper()
            if shootdown == "Y":
                playerresource -= 100
                botforplayermap[row][col] = hit
                break
            elif shootdown == "N":
                botforplayermap[row][col] = "*"
                break
            else:
                print("Invalid input! Input must be Y or N")
    else:
        botforplayermap[row][col] = "*"


    return botmaplist, botforplayermap, playerresource

def shipspresent(map): #Checks for ships in map that are not "U"
    lship = []
    for i in map:
        for j in i:
            if j in shiptypel:
                if j not in lship:
                    lship.append(j)
    return lship
def botturn(botforplayermap,yourmaplist,botresource,shipspresent,botmaplist,playerresource): #Bot turn
    print("Enemy is making his strategic move...")
    row = random.randint(0, boardsize -1 )
    col = random.randint(0, boardsize -1 )
    count = 0
    l = ["doNothing"]
    botships = shipspresent(botmaplist)
    if ("S" in botships) and botresource >= 350:
        l.append("S")
    if ("A" in botships) and botresource >= 400:
        l.append("A")
    if ("D" in botships) and botresource >= 300:
        l.append("D")
    if ("R" in botships) and botresource >= 650:
        l.append("R")
    abilitydecided = l[random.randint(0,len(l)-1)]
    if abilitydecided == "S":
        botmaplist,botresource = botspecialS(botmaplist,botresource)
    elif abilitydecided == "A":
        count,botresource,botmaplist = botspecialA(count,botresource,botmaplist)
    elif abilitydecided == "D":
        botmaplist,count,botresource = botspecialD(botmaplist,count,botresource)
    elif abilitydecided == "R":
        yourmaplist,botresource = botspecialR(yourmaplist,botresource)
    elif abilitydecided == "doNothing":
        pass
    while count < 1:
        row = random.randint(0, boardsize -1 )
        col = random.randint(0, boardsize -1 )
        if yourmaplist[row][col] in shiptypel:
            yourmaplist[row][col] = hit
            count += 1
        elif yourmaplist[row][col] == empty:
            yourmaplist[row][col] = miss
            count += 1
        elif yourmaplist[row][col] == "U":
            chance5050 = random.randint(0,1)
            subhit = input("Enemy has targeted undercover submarine! Dodge left or right? (L/R)")
            if chance5050 == 0:
                yourmaplist[row][col] = hit
                count += 1
            elif chance5050 == 1:
                count += 1
        else:
            space = False
            for i in yourmaplist:
                for j in i:
                    ll = [empty,"U","S","A","D","M","R"]
                    if j  in ll:
                        space = True
                        break
            if space == True:
                pass
            elif space == False:
                break
    print("Round over. Here are the enemy and friendly vessels status:")
    print("Your map:")
    printmap(yourmaplist)
    if devMode == True:
        print("Answer key:")
        printmap(botmaplist)
    print("Enemy side:")
    printmap(botforplayermap)
    playerresource += 300
    botresource += 300
    print("300 cash topup for both sides!\nCash left:",playerresource)
    input("Enter anything to continue")

    return botforplayermap,yourmaplist,botresource,shipspresent,botmaplist,playerresource

def botspecialA(count,botresource,botmaplist):
    for i in botmaplist:
        if "A" in i: #Repeats random shot 5 more times
            botresource -= 400
            print("Enemy has launched strike fighters!\nLocking in 5 random targets...")
            count -=5 #Stikes 5 random targets
            break
    return count,botresource,botmaplist
def botspecialR(yourmaplist,botresource):
    print("Enemy radar systems have locked onto a friendly vessel. Stike inbound, brace yourselves!")
    row = -1
    done = False#Same as player radar
    for i in yourmaplist:
        row +=1
        col = -1
        if done == True:
            break
        for j in i:
            col +=1
            if j in shiptypel:
                botresource -= 750
                yourmaplist[row][col] = hit
                done = True
                break
    return yourmaplist,botresource
def botspecialS(botmaplist,botresource):
    done = False
    row = -1#Same as player submarine
    for i in botmaplist:
        row +=1
        col = -1
        if done == True:
            break
        for j in i:
            col +=1
            botresource -= 350
            print("Intel has been provided that a submarine has gone undercover! (U)")
            botmaplist[row][col] = "U"
            done = True
            break
    return botmaplist,botresource
def botspecialD(botmaplist,count,botresource):#Repeats random shots 3 more times
    for i in botmaplist:
        if "D" in i:
            botresource -= 300
            count -= 3
            print("Enemy has brought in his destroyers!")
            break   # Repeats the shot 3 more times
    return botmaplist,count,botresource

def wincheck():
    winner = "No one"
    count = 0
    for i in botforplayermap:
        for j in i:
            if j == "X":
                count +=1
    if count >6 :
        winner = "Player"
        return winner
    count = 0
    for i in yourmaplist:
        for j in i:
            if j == "X":
                count +=1
    if count > 6:
        winner = "Enemy"
        return winner
    else:
        return winner


def openfile(file,animation): #Helps open files with option to use animation

    with open(file) as f:
        AsciiImage = f.read().split("\n")
        for line in AsciiImage:
            print(line)
            if animation == True:
                time.sleep(0.2)









#Intro
openfile("WelcomeMessage.txt",False)
print("\nConfidential document. Verify username to continue.\n")
name = input("Commander: ")
if name != devname:
    print("\nAccess granted.\n")
    openfile("Intro_text.txt",True)
    input("Enter anything to begin. ")
else:
    input("\nClearance level: HA verified. You now have access to classified intelligence. Enter anything to continue")

#Game Level decision. Allows player to change board size according to wants
while True:
    output.clear()
    levelsofd = {"Micro":5,"Normal":8,"Xtreme":10}
    boardsize = 5
    print("\n\nMicro Board: ")
    demo = createmap()
    printmap(demo)
    boardsize = 8
    print("\n\nNormal Board: ")
    demo = createmap()
    printmap(demo)
    boardsize = 10
    print("\n\nXtreme Board: ")
    demo = createmap()
    printmap(demo)
    difficulty = input("Choose a field size; the smaller the field, the faster the battle (Micro, Normal, Xtreme) ")
    if difficulty in levelsofd:
        boardsize = levelsofd[difficulty]
        break
output.clear()


botforplayermap = createmap()
yourmaplist = createmap()   #brings the map out into global
botmaplist = createmap()
if name == devname:
    devMode = True #This is a developer mode, used to save time while testing my code. Can also be used during time constraint presentation.
    playerresource = int(input("Amount for commander: "))
    botresource = int(input("Amount for enemy: "))
    print("Ship menu skipped")
    print("Generating random ship positions for you...")
    yourmaplist = randomshipplace(yourmaplist)
    print("Your map")
    printmap(yourmaplist)
else:
    output.clear()
    shipmenu()
    while True:
        ready = input("When you're ready to start, just give me the signal...   (Type: Ready)")
        if ready.lower() == "ready":
            output.clear()
            #break to game start
            break
        else:
            print("Not ready yet? It's fine...")
#START
    printmap(yourmaplist)
    while True:
        dywrandomplace = input("Would you like to have your ships randomly placed or manually placed? (Random/Manual)").lower()
        if dywrandomplace == "random":
            maneuvers = ["defensive", "evasive", "cover and concealment", "withdrawal", "disengagement", "shielding", "offensive", "flanking", "encirclement", "charge", "rush", "ambush", "overrun", "tactical", "strategic", "pincer movement", "retrograde movement", "envelopment", "infiltration", "spoiling attack", "aerial", "naval", "Immelmann turn", "Split-S", "barrel roll", "scissor maneuver", "Crazy Ivan", "psychological", "deceptive", "misdirection", "false retreat"]
            print(f"Ships moving into {random.choice(maneuvers)} positions.")
            print("Generating random ship positions for you...")
            yourmaplist = randomshipplace(yourmaplist)
            input("Enter anything to continue: ")
            break
        elif dywrandomplace == "manual":
            for i in range(7):
                print("We're in combat! Quickly, place 7 of your ships. Remember, when a ship dies, so does their ability! ")
                row,col,vessel = shipplace()
                yourmaplist[int(row)][int(col)] = shiptypesd[vessel]
                output.clear()
                print("Your map")
                printmap(yourmaplist)
            break
        else:
            print("Invalid input. Type \"Random\" or \"Manual \"")
    output.clear()
    print("Your map")
    printmap(yourmaplist)
print("Enemy is now making his strategic move...\n")
botmaplist = randomshipplace(botmaplist)
if devMode == True: #Dev Mode
    print("Answer key:")
    printmap(botmaplist)
#printmap(botmaplist) #to check if map printed for bot.

while True:
    print("Enemy is ready, are you?")
    ready = input("Are you ready?(Y/N): ")
    if ready == "Y":
        break
    else:
        print("Don't take your time commander",name+"!")
while True: #Loops player and bot turn until wincheck does not return a tie
    output.clear()
    botforplayermap,yourmaplist,playerresource,shipspresent,botmaplist = playerturn(botforplayermap,yourmaplist,playerresource,shipspresent,botmaplist)
    output.clear()
    if wincheck() != "No one":
        break
    botforplayermap,yourmaplist,botresource,shipspresent,botmaplist,playerresource = botturn(botforplayermap,yourmaplist,botresource,shipspresent,botmaplist,playerresource)
    if wincheck() != "No one":
        break
output.clear()
#Win messages
if wincheck() == "Player":
    winningplayer = "The United States of America"
else:
    winningplayer = "China"
for i in f"It is over. {winningplayer} has won the Invisible War.\n":
    time.sleep(0.45)
    print(i,end = "")
if wincheck() == "Player":
    print("")
    print("YOU WIN! CONGRATS SIR",name.upper())
    time.sleep(2)
    print("\n Wait! We are receiving an emergency action message from the pentagon.\nStandby...")
    output.clear()
    openfile("Victory_Message.txt", True)
    input("Enter anything to continue:")
    output.clear()
else:
    openfile("Lose_Message.txt",True)
    while True:
        resign = input("Do you accept resignation? (Y/N) ")
        if resign == "Y":
            print("All the best for your future endavours!")
            time.sleep(2)
            output.clear()
            break
        else:
            print("Well too bad, you're fired!")
            output.clear()
            break

print(f"""Battle Analysis:

War: Invisible War
Date:7December
Location:North Pacific
Belligerents: United States of America and China
Commanders: US:{name} and China: Xiao Xiao Ming
Forces engaged: US: {random.randint(7000,9000)} China: {random.randint(7000,9000)}
Casualties: US:{random.randint(100,2000) if winningplayer == "The United States of America" else random.randint(5000,6900)} China: {random.randint(100,2000) if winningplayer == "China" else random.randint(5000,6900)}
Outcome: {"Unexpected US Victory" if winningplayer=="The United States of America" else "Decisive Chinese Victory"}


""")
print("Your map:")
printmap(yourmaplist)
print("Enemy's ships:")
printmap(botmaplist)
print("Your strikes:")
printmap(botforplayermap)
print(f"\n\nYour final credits: {playerresource}\nEnemy's final credits: {botresource}")
input("Enter anything to continue")
output.clear()
end = (f"Well this is it.\nThank you sir {name} for fighting till the very end. \nSee you around\nIt has been an honour...")
for i in end:
    print(i,end = "")
    time.sleep(0.07)
time.sleep(2)
output.clear()
openfile("WelcomeMessage.txt", False)

#Thats a wrap!
## Personal logs of previous bugs and fixes at the bottom!!

# %% [markdown]
# #File Upload PLEASE RUN BEFORE MAIN
# special thanks to https://seotoolbelt.co/tools/ascii-art-generator/#csv-tab (Image to Ascii Generator)

# %%
with open("WelcomeMessage.txt", "w") as f:
    f.write("""
______          _           _       ___                           _
| ___ \        (_)         | |     / _ \                         | |
| |_/ / __ ___  _  ___  ___| |_   / /_\ \_ __ _ __ ___   __ _  __| | __ _
|  __/ '__/ _ \| |/ _ \/ __| __|  |  _  | '__| '_ ` _ \ / _` |/ _` |/ _` |
| |  | | | (_) | |  __/ (__| |_   | | | | |  | | | | | | (_| | (_| | (_| |
\_|  |_|  \___/| |\___|\___|\__|  \_| |_/_|  |_| |_| |_|\__,_|\__,_|\__,_|
              _/ |
             |__/
by elisaysha_

                                                                                              """)
with open("oldWelcomeMessage.txt", "w") as f:
    f.write("""
 _    _      _                             _            ___                           _
| |  | |    | |                           | |          / _ \                         | |
| |  | | ___| | ___ ___  _ __ ___   ___   | |_ ___    / /_\ \_ __ _ __ ___   __ _  __| | __ _
| |/\| |/ _ \ |/ __/ _ \| '_ ` _ \ / _ \  | __/ _ \   |  _  | '__| '_ ` _ \ / _` |/ _` |/ _` |
\  /\  /  __/ | (_| (_) | | | | | |  __/  | || (_) |  | | | | |  | | | | | | (_| | (_| | (_| |
 \/  \/ \___|_|\___\___/|_| |_| |_|\___|   \__\___/   \_| |_/_|  |_| |_| |_|\__,_|\__,_|\__,_|
by elisaysha_

                                                                                              """)
with open("DestroyerImage.txt", "w") as f:
    f.write(""" . . . . . . . . . . . .. . .  0. . . . .. . . . . . . ..
. .. .. .. .. . . . . . . . .[aaaaaa.. . . . . . . . . . .
 . . . . . . . . . .. .'ttOa~aaaaaaa~. . . . . . .. . . .
. . . . ..J.  . . ... `llraacaaawphax . . . . . . . . . .
 . . . . . .OZOZf.`CZwkhhdhaqhhwhphpbqwaaa~. .. . . .. . .
. . .  UaaaaaaaaaaaaaUtt/t/t/t/t/t/t/ttt-tt . . . . . . .
 .. ....'qaaaaaaeshaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa^ . ..
. . .  . . qaaaaaaaaaaaaelisaysha_aaaaaaaaaaaaaaaaaU . . .
 . . . . ... IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII .. . . """)
with open("JetImage.txt", "w") as f:
    f.write("""                                                  {C|
                                                M&$1.
                                            "XB$$8|
                                          .z$$$$o
                                        fh$$$$$}
            {f.                    Q8 _@$$$$$j.
          ~%n                   'j$$$$$$$$$8j
        ]M$t                    L$$$$$$$$$x
      # !o$$_                  .X$$$$$$$$$$$w
    '@$$elisaysha_$$@f``''`'|$$$$$$$$$$$$%
  lq$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$Bb_
^0$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$/'
l "!#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$t.
      }8$$$$$$$$$$$$$$$$$$$$$$$$$$x
        (C@$$$$$$$$$$$$$$$$$$$$$$$n
           r%$$$$$$$$$$$$$$$$$$$$$x
             ^q$$$$$$$$$$$$$$$$$$$o~
              I8$$$$$$$$$$$$$$$$$$$[
   # ?ftfffJ$$$$$$$$$$$$$$$$$$$$$$$$$]
  r$$$$$$$$$$$$$$$$$O$$$$$$$$$$$$$$[
    '`-$$$$$$$$$$$v. ,$$$$$$$$$$$$$$:      +
         >@$$$$$$$u   io$$$$$$$$$$$$; ^+mk
         b$Wm$$$$8|     [W$$$$$$$$$$z@$di
             c$$$O       >@$$$$$$$$$$8i
              w$$Z         ]$$$$$$$B;
              c@$O          -*esh_{
               |(            >a$)
                             r}.  """)
with open("MissileImage.txt", "w") as f:
    f.write("""
                                                   $$$$$$
                                               $$$$$$$$$$
                                            $$$$$$  $$$$
                                        $$$$$$    $$$$$
                                       $$$$$     $$$$$
                                     $$$$       $$$$
                                   $$$$$$      $$$$
                                 $$$$$ $$$$   $$$$
                         $$$$$$$$$$$$$$ $$$$$$$$
                   $$$$$$$$$$$$$$$   $$$$ $$$$$
                   $$$$$$  $$$$  $$$$  $$$$$
                    $$$$$$$$$  $$$$$  $$$$
                       $$$$$ $$$$$  $$$$
                     $$$$$  $$$$  $$$$$$
                   $$$$$$$  $$  $$$$$ $$
             $$$$$$$$$ $$$$$  esh$$  $$$
       $$$$$$$$$$$$$     $$$$$$$$$$$ $$
     $$$$$$   $$$$$ $$$$   $$$$  $$$ $$
  $$$$$    $$$$$  $$$$  $$$$$     $$$$$
  $$$$$$  $$$$  $$$$  $$$$$$
    $$$$$$$$  $$$$$ $$$$$$$
      $$$$  $$$$$  $$$$$$$$
      $$$  $$$$  $$$$  $$$
     $$$$$     $$$$   $$$$
   $$$$$$$$  $$$$$    $$$
    $$elisaysha_$$$ $$$$
      $$$$      $$$$$$
                 $$$
                              """)
with open("RadarImage.txt", "w") as f:
    f.write("""
                                   ..
                                  ,z@%qu{^
                                  :Q8@$@$@dj!
                                     `_vq@$@$Z_.
                                .if>     I/d@$@w_.
                                :M@@$#Y}'   -d$@$LI
                                ^nvw@@$@MJ~   {a@@M~.
                                    '<J8@$%YI  >p$@@?.
                                'l:    ;c&$@q+  ^m$@$i
                             iJ$@$@@o1   _p$@d_  ,d@@#:
                 [n!        -@$@&YZ$@@Q   [h$@c,  (#MJ,.
               _q@$@LI      8@$M  `|$$b+   n@&Z~
              }h$@$@$@U:    )$@@dnY@@@O'
             _p@$Z_f#@$@X^.n@@$@$@@$Mn"
             j@$8)  "rM$@$@@$@x"{xf<
               ."`    "n&$@$@'
               `?i      ,v%$@@r
             i0@$L!       :X@@$8f
              )*@$m>        :U@$@W|
               r8@$@Zj:      ^Y$@$$p
              _q$@$@@$@$&aa&$@@$@#|
             # ?elisaysha_@$@$@&UrI
            }o$@m<]h@@*!
          .)&@$0>  +k@$8<
         '/@@$CI    Ib@$@?.
  ._zzXzXZ$@$oCzzXzzXJW@$$UzXzzc_
  't@$@$@@$@@$@$$@$@$@$@$@$@$@$8f
   "iii!iiiiiiii!ieshiii!iiiiii!,
                                                          """)
with open("SubmarineImage.txt", "w") as f:
    f.write("""                                              .%
                                               ^. .B
                                             l)jjfjBffu*[
                                            f&$$$$$$$$$$q
                                            z@$$$$$$$$$$q
           ;p$Y^        .>||||||/|||||/|||||w$$$$$$$$$$$o|||||||||||8|||(+
           # ?a$$u'jrnq$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$*X]`
           # ?a$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$(.
       tu :Y8$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$@[
      IJ0{{p$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$@t'
       :I  C@ESH[--1#@@$$@$$$$$$$$$$$$$$$$$$$$$$$elisaysha_$$$$$$$$$$$$$$$$@Z-i`
           .l<<.          :<<<<<<><<<<<<<<<<<<><<><<><><<><<<<<<<<`""")

with open("Lose_Message.txt", "w") as f:
    f.write("""Rank: Secretary of Defence
Address: 1000 Navy Pentagon, Washington, DC
Email: USNavy@defence.gov.com
Date: 7 December 2067
To Fleet Admiral:

Dear Fleet Admiral,
I am writing to address the recent unfortunate events involving your command, which resulted in significant
losses and the failure to protect our vessels and its crew from enemy forces. Under your leadership, all 7 of
your ships have been destroyed.

As the secertary of defence, it is my job to ensure the highest standards of perfomance in our leadership.
Regretabily, these recent events have lapsed these critical areas under your command. You will be asked to attend
a court-martial upon arrival back to the United States of America and investigated.

Given the gravity of the situation and the need to maintain integrity and trust in our naval leadership, I must
ask for your resignation of Admiral in the United States Navy effective immediately. This decision though difficult,
is necessary to uphold the standards that built our military.

On behalf of the United States Navy, we thank you for all the years of service and dedication to the forces.
Please understand that this decision was made with the best interest of our armed forces in mind. I trust you accept this
decision with a sense of responsibility and leadership in mind.

Thank you for your attention to this matter.



Sincerely,
Secetary of Defense
elisaysha_
United States of America""")

with open("Vicotry_Message.txt", "w") as f:
    f.write("""Rank: Secretary of Defence
Address: 1000 Navy Pentagon, Washington, DC
Email: USNavy@defence.gov.com
Date: 7 December 2067
To Fleet Admiral:

Dear Fleet Admiral,

Congratulations on your recent victory against China’s commanding fleet, ShenZhong. Shortly after its final vessel was neutralized,
the cloaking technology concealing the remaining Chinese forces collapsed. This allowed the United States Air Force to execute an
aerial sweep of the territory reducing China’s invisible fleet to dust.

Your leadership of Fleet Armada has been nothing short of legendary. In the darkest hour, when all others had fallen, it was Armada
that stood firm. Your command turned the tides of this war, securing our greatest triumph

You are hereby recommended for the Medal of Honor, pending final approval by the Defense Council. Your actions during
Operation: Armada will be commemorated at the upcoming Joint Forces Commendation Ceremony.

With that said, though ShenZhong has fallen, our latest intelligence suggests scattered rogue units may still linger beneath the waves.
Should they rise again, the legacy of Armada will stand ready.

You have restored peace, inspired a nation, and carved the name Armada into the annals of history.

For freedom, for Earth, for all mankind.



Sincerely,
Secetary of Defense
elisaysha_
United States of America""")










with open("Intro_text.txt", "w") as f:
    f.write("""

Year 2067 – Operation: Armada


    Ten years ago, an alien ship the size of a city descended into the North Pacific. They offered humanity technology in exchange for knowledge.
    But days later, they vanished. No trace, no evidence, no media. Just silence.

    What the world didn’t know: the ship had turned invisible.
    Only the US and China were aware. Tensions rose. The US sought peaceful exchange. China wanted alien tech, by force.

    Without warning, China launched six missile strikes. The resulting chaos, unseen by the public, became known as The Invisible War.

    The alien ship crashed into the ocean. Death confirmed by intelligence from both countries.
    Both nations scavenged what they could, using the tech to cloak fleets, fight blind, and wage a silent war beneath the waves,hidden from the world.

    Now, in 2067, China is winning. The US has only one invisible fleet left: Codename: Armada.

    You are its commander.

    Your mission: infiltrate the North Pacific, locate and destroy China’s invisible command fleet, the ShenZhong. Win this battle, end the war.

    The fate of America rides with you.

    Good luck, Commander.





    """)












with open("ShipMenu.txt", "w") as f:
    f.write("""
    Nimitz-class	Aircraft carrier (A);   Ability to send planes and strike 5 random targets;    400 Credits;
    Virginia-class    Attack submarine (S); Ability to hide underwater for 2 rounds;     350 Credits
    Ticonderoga-class    Missile Cruiser (M);    Ability to shoot 1 missile that does a 2x2 splash attack;     300 Credits
    SBX-1 Sea-based X-band Radar (R);    Ability to reveal exact location of 1 random enemy target;   650 Credits
    Arleigh Burke-class	Destroyer (D);     Ability to shoot 3 specific targets;  300 Credits\n\n""")

# %% [markdown]
# #Personal Logs: (Nothing to see here, its boring)
#
# Previous bugs and fixes:
#
#         ##Submarine wouln't resurface Fix: have the sub submerged entire game, but 2/3 dodging instead. Turns to work out since submerging sub for one round only will throw problems when enemy attacks submerged sub
#         ##decide on board size       Fix: (Board size can be changed)
#         ##wincheck error             Fix: just use another method of counting the number of X LOL
#         ##add lose letter (Above)       Fix: Instead of manually downloading all ascii images, decided to create a second code cell with all the art to download as files instead using "w"
#         ##submarine message deleted by output clear         Fix: Simple fix of adding the "Enter anything to continue option" (Added to other parts of code to help)
#         ##bot randint on special ability            Fix: Bot will now randomly choose an ability within his resource instead of using the most expensive ability
#         ##radar showing multiple locations              Fix: carelss logic error that caused 3 hours of confusion haiz...
#         ##Missile splash not working as expected on small map, missile splash and submarine undercover       Fix: Problem caused when trying to use shorter code, backfired as long code needed to retain important qualities
#         ## Found a bug where bot hangs when there is no possible input to shoot due to submerged submarine (CREDITS JIANNN)         Fix: bot breaks when he encounters similar situaiton
